# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h5>for theory/practicle of Random Forest visit :<b> https://github.com/aadi-254/machine_learning </b> <h5>

# %% [markdown]
# ### parameters
#
# Num estimator = no of decision trees <br>
# max feature = NO. of cell<br>
# Max Sample = NO of rows<br>
# boostraping : True/False

# %%
## 🎉 Streamlit Application Created!

### How to Run the Application:

1. **Open Terminal** and run:
   ```bash
   streamlit run app.py
   ```

2. **Features of the Application:**
   - 🎯 **Classification Mode**: Uses 700-sample synthetic dataset with 10 features and 3 classes
   - 📈 **Regression Mode**: Uses 700-sample synthetic dataset with 10 features
   - ⚙️ **Adjustable Parameters**:
     - Number of Estimators (10-500)
     - Max Features (sqrt, log2, None)
     - Max Samples (0.1-1.0)
     - Bootstrap (True/False)
     - Max Depth
     - Min Samples Split
     - Min Samples Leaf
     - Test Set Size
     - Random State

3. **Three Tabs Available:**
   - 📊 **Dataset & Results**: View dataset info, model performance metrics, and feature importance
   - 📈 **Visualizations**: Interactive plots including confusion matrix, actual vs predicted, residual plots
   - ℹ️ **About**: Learn about Random Forest algorithm and parameters

### The app automatically generates new datasets and trains the model in real-time as you adjust parameters!
